# %%
import pandas as pd
import numpy as np
import os
import glob
import joblib

from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_classif
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score

DATA_DIR = '../data'  
MODEL_DIR = '../models'
MIN_DATA_POINTS = 252 

SP500_TICKER_FILE = os.path.join(DATA_DIR, 'sp500_tickers_correct.csv')

os.makedirs(MODEL_DIR, exist_ok=True)

def get_sp500_tickers_from_csv(file_path):
    try:
        df = pd.read_csv(file_path)
        if 'Symbol' not in df.columns:
            print(f"HATA: '{file_path}' dosyasında 'Symbol' sütunu bulunamadı.")
            return None
        
        tickers = df['Symbol'].tolist()
        print(f"'{file_path}' dosyasından {len(tickers)} adet S&P 500 hisse senedi sembolü başarıyla okundu.")
        return tickers
    except FileNotFoundError:
        print(f"HATA: S&P 500 ticker dosyası bulunamadı: '{file_path}'")
        print("Lütfen önce 'scrape_sp500.py' dosyasını çalıştırdığınızdan emin olun.")
        return None
    except Exception as e:
        print(f"HATA: S&P 500 listesi okunurken bir hata oluştu: {e}")
        return None

# %%
def load_and_clean_data(file_path):
    try:
        df = pd.read_csv(file_path)
        stock_ticker = os.path.basename(file_path).split('.')[0]
        print(f"--- {stock_ticker} verisi işleniyor... ---")

        required_cols = ['Date', 'Open', 'High', 'Low', 'Close', 'Volume']
        if not all(col in df.columns for col in required_cols):
            print(f"HATA: {stock_ticker}.csv dosyasında gerekli sütunlar bulunamadı. Atlanıyor.")
            return None, None

        df['Date'] = pd.to_datetime(df['Date'])
        df.set_index('Date', inplace=True)
        
        df.dropna(how='any', inplace=True)

        price_cols = ['Open', 'High', 'Low', 'Close', 'Volume']
        df = df[(df[price_cols] > 0).all(axis=1)]

        if len(df) < MIN_DATA_POINTS:
            print(f"UYARI: {stock_ticker} için yeterli veri yok ({len(df)} satır). Atlanıyor.")
            return None, None
        
        return df, stock_ticker
    except Exception as e:
        print(f"HATA: {file_path} işlenirken bir hata oluştu: {e}. Atlanıyor.")
        return None, None

# %%
def feature_engineering(df):
    df['EMA_10'] = df['Close'].ewm(span=10, adjust=False).mean()
    df['EMA_20'] = df['Close'].ewm(span=20, adjust=False).mean()
    df['EMA_50'] = df['Close'].ewm(span=50, adjust=False).mean()

    delta = df['Close'].diff(1)
    gain = delta.where(delta > 0, 0)
    loss = -delta.where(delta < 0, 0)
    avg_gain = gain.rolling(window=14).mean()
    avg_loss = loss.rolling(window=14).mean()
    rs = avg_gain / avg_loss
    df['RSI'] = 100 - (100 / (1 + rs))

    high_low = df['High'] - df['Low']
    high_close = np.abs(df['High'] - df['Close'].shift())
    low_close = np.abs(df['Low'] - df['Close'].shift())
    ranges = pd.concat([high_low, high_close, low_close], axis=1)
    true_range = np.max(ranges, axis=1)
    df['ATR'] = true_range.rolling(window=14).mean()

    df['Target'] = (df['Close'] > df['Open']).astype(int)
    df['Target'] = df['Target'].shift(-1)
    df.dropna(inplace=True)
    df['Target'] = df['Target'].astype(int)
    
    return df

# %%
def create_windowed_dataset(X, y, window_size=5):
    X_windowed, y_windowed = [], []
    for i in range(window_size, len(X)):
        features = X.iloc[i-window_size:i].values.flatten()
        X_windowed.append(features)
        y_windowed.append(y.iloc[i])
    return np.array(X_windowed), np.array(y_windowed)

from xgboost import XGBClassifier

def run_experiments_for_stock(df, stock_ticker):
    X_full = df.drop('Target', axis=1)
    y_full = df['Target']
    stock_results = []
    
    feature_subsets = { 'Tum_Ozellikler': X_full.columns.tolist(), 'Sadece_Teknik_Indikatorler': ['EMA_10', 'EMA_20', 'EMA_50', 'RSI', 'ATR'] }
    k_values = [5, 10, 15]
    window_sizes = [3, 7]
    split_ratio = 0.8
    
    for subset_name, subset_columns in feature_subsets.items():
        X_subset = X_full[subset_columns]
        for k in k_values:
            current_k = min(k, X_subset.shape[1])
            if k > current_k: continue
            for window in window_sizes:
                print(f"\n--- Deney: {subset_name} | k={current_k} | Pencere={window} ---")
                
                selector = SelectKBest(f_classif, k=current_k).fit(X_subset, y_full)
                X_selected = X_subset[X_subset.columns[selector.get_support()]]
                X_windowed, y_windowed = create_windowed_dataset(X_selected, y_full, window_size=window)
                if len(X_windowed) == 0: continue
                
                split_index = int(len(X_windowed) * split_ratio)
                X_train_w, X_test_w = X_windowed[:split_index], X_windowed[split_index:]
                y_train_w, y_test_w = y_windowed[:split_index], y_windowed[split_index:]
                
                scaler = StandardScaler().fit(X_train_w)
                X_train_scaled = scaler.transform(X_train_w)
                X_test_scaled = scaler.transform(X_test_w)
                
                model = XGBClassifier(eval_metric='logloss', random_state=42).fit(X_train_scaled, y_train_w)
                y_pred = model.predict(X_test_scaled)
                accuracy = accuracy_score(y_test_w, y_pred)
                
                model_filename = os.path.join(MODEL_DIR, f"xgb_{stock_ticker}_subset-{subset_name}_k{current_k}_w{window}.joblib")
                joblib.dump(model, model_filename)
                stock_results.append({ 'model_tipi': 'XGBoost', 'hisse_senedi': stock_ticker, 'alt_kume': subset_name, 'k_ozellik_sayisi': current_k, 'pencere_boyutu': window, 'dogruluk': accuracy, 'model_dosyasi': model_filename })
    
    print(f"==> {stock_ticker} için {len(stock_results)} deneyi tamamlandı.")
    return stock_results

# %%
def main():
    sp500_tickers = get_sp500_tickers_from_csv(SP500_TICKER_FILE)
    if sp500_tickers is None:
        return 
    
    all_csv_files = glob.glob(os.path.join(DATA_DIR, '*.csv'))
    if not all_csv_files:
        print(f"UYARI: '{DATA_DIR}' klasöründe hiçbir .csv dosyası bulunamadı.")
        return

    target_csv_files = []
    sp500_set = set(sp500_tickers)
    for file_path in all_csv_files:
        ticker = os.path.basename(file_path).split('.')[0]
        if ticker in sp500_set:
            target_csv_files.append(file_path)
            
    print(f"\nİşlenecek {len(target_csv_files)} adet S&P 500 hissesi bulundu.")

    all_results = []
    for file_path in target_csv_files:
        df_clean, stock_ticker = load_and_clean_data(file_path)
        if df_clean is None:
            continue
            
        df_featured = feature_engineering(df_clean)
        if len(df_featured) < MIN_DATA_POINTS:
            print(f"UYARI: {stock_ticker} için özellik mühendisliği sonrası yeterli veri kalmadı. Atlanıyor.")
            continue
        
        results_for_one_stock = run_experiments_for_stock(df_featured, stock_ticker)
        all_results.extend(results_for_one_stock)

    print("\n--- TÜM HİSSE SENETLERİ İÇİN TÜM DENEYLER TAMAMLANDI ---")

    if not all_results:
        print("Hiçbir hisse senedi için başarılı bir deney sonucu elde edilemedi.")
        return
        
    results_df = pd.DataFrame(all_results)
    results_df_sorted = results_df.sort_values(by=['hisse_senedi', 'dogruluk'], ascending=[True, False])

    print("\nBirleştirilmiş Deney Sonuçları Tablosu:")
    display(results_df_sorted)

if __name__ == '__main__':
    main()
# Out:
# '../data/sp500_tickers_correct.csv' dosyasından 503 adet S&P 500 hisse senedi sembolü başarıyla okundu.
#
# İşlenecek 472 adet S&P 500 hissesi bulundu.
# --- MGM verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> MGM için 6 deneyi tamamlandı.
# --- FAST verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> FAST için 6 deneyi tamamlandı.
# --- WFC verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> WFC için 6 deneyi tamamlandı.
# --- DUK verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> DUK için 6 deneyi tamamlandı.
# --- PNC verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> PNC için 6 deneyi tamamlandı.
# --- CFG verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> CFG için 6 deneyi tamamlandı.
# --- TTWO verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> TTWO için 6 deneyi tamamlandı.
# --- QCOM verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> QCOM için 6 deneyi tamamlandı.
# --- MU verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> MU için 6 deneyi tamamlandı.
# --- NKE verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> NKE için 6 deneyi tamamlandı.
# --- AIG verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> AIG için 6 deneyi tamamlandı.
# --- TSLA verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> TSLA için 6 deneyi tamamlandı.
# --- HSIC verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> HSIC için 6 deneyi tamamlandı.
# --- V verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> V için 6 deneyi tamamlandı.
# --- MRK verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> MRK için 6 deneyi tamamlandı.
# --- MET verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> MET için 6 deneyi tamamlandı.
# --- MRNA verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> MRNA için 6 deneyi tamamlandı.
# --- ENPH verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> ENPH için 6 deneyi tamamlandı.
# --- NWS verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> NWS için 6 deneyi tamamlandı.
# --- OXY verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> OXY için 6 deneyi tamamlandı.
# --- TXT verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> TXT için 6 deneyi tamamlandı.
# --- COF verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> COF için 6 deneyi tamamlandı.
# --- PPG verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> PPG için 6 deneyi tamamlandı.
# --- SMCI verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> SMCI için 6 deneyi tamamlandı.
# --- CSGP verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> CSGP için 6 deneyi tamamlandı.
# --- BRO verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> BRO için 6 deneyi tamamlandı.
# --- LRCX verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> LRCX için 6 deneyi tamamlandı.
# --- LOW verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> LOW için 6 deneyi tamamlandı.
# --- COST verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> COST için 6 deneyi tamamlandı.
# --- ULTA verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> ULTA için 6 deneyi tamamlandı.
# --- KMI verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> KMI için 6 deneyi tamamlandı.
# --- WSM verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> WSM için 6 deneyi tamamlandı.
# --- AEE verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> AEE için 6 deneyi tamamlandı.
# --- MO verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> MO için 6 deneyi tamamlandı.
# --- PEP verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> PEP için 6 deneyi tamamlandı.
# --- BAC verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> BAC için 6 deneyi tamamlandı.
# --- AMZN verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> AMZN için 6 deneyi tamamlandı.
# --- EMN verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> EMN için 6 deneyi tamamlandı.
# --- JCI verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> JCI için 6 deneyi tamamlandı.
# --- BMY verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> BMY için 6 deneyi tamamlandı.
# --- MLM verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> MLM için 6 deneyi tamamlandı.
# --- RF verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> RF için 6 deneyi tamamlandı.
# --- KKR verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> KKR için 6 deneyi tamamlandı.
# --- WAB verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> WAB için 6 deneyi tamamlandı.
# --- MKTX verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> MKTX için 6 deneyi tamamlandı.
# --- NEE verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> NEE için 6 deneyi tamamlandı.
# --- CDW verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> CDW için 6 deneyi tamamlandı.
# --- TFC verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> TFC için 6 deneyi tamamlandı.
# --- HOLX verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> HOLX için 6 deneyi tamamlandı.
# --- HAL verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> HAL için 6 deneyi tamamlandı.
# --- CMS verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> CMS için 6 deneyi tamamlandı.
# --- BLK verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> BLK için 6 deneyi tamamlandı.
# --- PTC verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> PTC için 6 deneyi tamamlandı.
# --- KR verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> KR için 6 deneyi tamamlandı.
# --- ADSK verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> ADSK için 6 deneyi tamamlandı.
# --- HUBB verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> HUBB için 6 deneyi tamamlandı.
# --- WYNN verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> WYNN için 6 deneyi tamamlandı.
# --- TAP verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> TAP için 6 deneyi tamamlandı.
# --- DAL verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> DAL için 6 deneyi tamamlandı.
# --- EBAY verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> EBAY için 6 deneyi tamamlandı.
# --- RCL verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> RCL için 6 deneyi tamamlandı.
# --- DVA verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> DVA için 6 deneyi tamamlandı.
# --- BLDR verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> BLDR için 6 deneyi tamamlandı.
# --- D verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> D için 6 deneyi tamamlandı.
# --- MOH verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> MOH için 6 deneyi tamamlandı.
# --- MSCI verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> MSCI için 6 deneyi tamamlandı.
# --- KLAC verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> KLAC için 6 deneyi tamamlandı.
# --- AMGN verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> AMGN için 6 deneyi tamamlandı.
# --- DHR verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> DHR için 6 deneyi tamamlandı.
# --- VTR verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> VTR için 6 deneyi tamamlandı.
# --- TER verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> TER için 6 deneyi tamamlandı.
# --- GDDY verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> GDDY için 6 deneyi tamamlandı.
# --- CMCSA verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> CMCSA için 6 deneyi tamamlandı.
# --- XEL verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> XEL için 6 deneyi tamamlandı.
# --- NOW verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> NOW için 6 deneyi tamamlandı.
# --- ALGN verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> ALGN için 6 deneyi tamamlandı.
# --- LUV verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> LUV için 6 deneyi tamamlandı.
# --- UHS verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> UHS için 6 deneyi tamamlandı.
# --- HON verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> HON için 6 deneyi tamamlandı.
# --- EVRG verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> EVRG için 6 deneyi tamamlandı.
# --- JNJ verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> JNJ için 6 deneyi tamamlandı.
# --- CMI verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> CMI için 6 deneyi tamamlandı.
# --- DE verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> DE için 6 deneyi tamamlandı.
# --- PNR verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> PNR için 6 deneyi tamamlandı.
# --- ADM verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> ADM için 6 deneyi tamamlandı.
# --- ORCL verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> ORCL için 6 deneyi tamamlandı.
# --- VICI verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> VICI için 6 deneyi tamamlandı.
# --- WY verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> WY için 6 deneyi tamamlandı.
# --- VRTX verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> VRTX için 6 deneyi tamamlandı.
# --- CME verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> CME için 6 deneyi tamamlandı.
# --- DRI verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> DRI için 6 deneyi tamamlandı.
# --- EPAM verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> EPAM için 6 deneyi tamamlandı.
# --- BKR verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> BKR için 6 deneyi tamamlandı.
# --- JPM verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> JPM için 6 deneyi tamamlandı.
# --- IEX verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> IEX için 6 deneyi tamamlandı.
# --- FOXA verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> FOXA için 6 deneyi tamamlandı.
# --- AEP verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> AEP için 6 deneyi tamamlandı.
# --- NEM verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> NEM için 6 deneyi tamamlandı.
# --- NDSN verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> NDSN için 6 deneyi tamamlandı.
# --- ANSS verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> ANSS için 6 deneyi tamamlandı.
# --- DLTR verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> DLTR için 6 deneyi tamamlandı.
# --- UNH verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> UNH için 6 deneyi tamamlandı.
# --- KO verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> KO için 6 deneyi tamamlandı.
# --- NRG verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> NRG için 6 deneyi tamamlandı.
# --- ES verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> ES için 6 deneyi tamamlandı.
# --- NI verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> NI için 6 deneyi tamamlandı.
# --- ETR verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> ETR için 6 deneyi tamamlandı.
# --- KHC verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> KHC için 6 deneyi tamamlandı.
# --- CPRT verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> CPRT için 6 deneyi tamamlandı.
# --- TMUS verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> TMUS için 6 deneyi tamamlandı.
# --- TDY verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> TDY için 6 deneyi tamamlandı.
# --- LKQ verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> LKQ için 6 deneyi tamamlandı.
# --- BAX verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> BAX için 6 deneyi tamamlandı.
# --- INVH verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> INVH için 6 deneyi tamamlandı.
# --- CLX verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> CLX için 6 deneyi tamamlandı.
# --- COR verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> COR için 6 deneyi tamamlandı.
# --- BX verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> BX için 6 deneyi tamamlandı.
# --- K verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> K için 6 deneyi tamamlandı.
# --- C verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> C için 6 deneyi tamamlandı.
# --- MSFT verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> MSFT için 6 deneyi tamamlandı.
# --- NFLX verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> NFLX için 6 deneyi tamamlandı.
# --- COO verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> COO için 6 deneyi tamamlandı.
# --- T verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> T için 6 deneyi tamamlandı.
# --- ABBV verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# ...
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> MKC için 6 deneyi tamamlandı.
# --- TGT verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> TGT için 6 deneyi tamamlandı.
# --- ALB verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> ALB için 6 deneyi tamamlandı.
# --- SBUX verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> SBUX için 6 deneyi tamamlandı.
# --- CRL verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> CRL için 6 deneyi tamamlandı.
# --- LMT verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> LMT için 6 deneyi tamamlandı.
# --- CCI verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> CCI için 6 deneyi tamamlandı.
# --- GS verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> GS için 6 deneyi tamamlandı.
# --- UNP verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> UNP için 6 deneyi tamamlandı.
# --- J verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> J için 6 deneyi tamamlandı.
# --- LH verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> LH için 6 deneyi tamamlandı.
# --- VRSK verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> VRSK için 6 deneyi tamamlandı.
# --- AMCR verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> AMCR için 6 deneyi tamamlandı.
# --- MCO verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> MCO için 6 deneyi tamamlandı.
# --- STX verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> STX için 6 deneyi tamamlandı.
# --- MTCH verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> MTCH için 6 deneyi tamamlandı.
# --- LII verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> LII için 6 deneyi tamamlandı.
# --- PODD verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> PODD için 6 deneyi tamamlandı.
# --- ABT verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> ABT için 6 deneyi tamamlandı.
# --- PNW verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> PNW için 6 deneyi tamamlandı.
# --- SCHW verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> SCHW için 6 deneyi tamamlandı.
# --- PM verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> PM için 6 deneyi tamamlandı.
# --- EL verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> EL için 6 deneyi tamamlandı.
# --- EQR verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> EQR için 6 deneyi tamamlandı.
# --- IQV verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> IQV için 6 deneyi tamamlandı.
# --- BR verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> BR için 6 deneyi tamamlandı.
# --- XYL verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> XYL için 6 deneyi tamamlandı.
# --- MDT verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> MDT için 6 deneyi tamamlandı.
# --- F verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> F için 6 deneyi tamamlandı.
# --- MDLZ verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> MDLZ için 6 deneyi tamamlandı.
# --- FE verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> FE için 6 deneyi tamamlandı.
# --- SHW verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> SHW için 6 deneyi tamamlandı.
# --- MPWR verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> MPWR için 6 deneyi tamamlandı.
# --- ADP verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> ADP için 6 deneyi tamamlandı.
# --- TYL verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> TYL için 6 deneyi tamamlandı.
# --- PANW verisi işleniyor... ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=5 | Pencere=7 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=3 ---
#
# --- Deney: Tum_Ozellikler | k=10 | Pencere=7 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=3 ---
#
# --- Deney: Sadece_Teknik_Indikatorler | k=5 | Pencere=7 ---
# ==> PANW için 6 deneyi tamamlandı.
#
# --- TÜM HİSSE SENETLERİ İÇİN TÜM DENEYLER TAMAMLANDI ---
#
# Birleştirilmiş Deney Sonuçları Tablosu:
#      model_tipi hisse_senedi                    alt_kume  k_ozellik_sayisi  \
# 1339    XGBoost            A              Tum_Ozellikler                 5
# 1341    XGBoost            A              Tum_Ozellikler                10
# 1343    XGBoost            A  Sadece_Teknik_Indikatorler                 5
# 1340    XGBoost            A              Tum_Ozellikler                10
# 1338    XGBoost            A              Tum_Ozellikler                 5
# ...         ...          ...                         ...               ...
# 1348    XGBoost          ZTS  Sadece_Teknik_Indikatorler                 5
# 1347    XGBoost          ZTS              Tum_Ozellikler                10
# 1345    XGBoost          ZTS              Tum_Ozellikler                 5
# 1346    XGBoost          ZTS              Tum_Ozellikler                10
# 1349    XGBoost          ZTS  Sadece_Teknik_Indikatorler                 5
#
#       pencere_boyutu  dogruluk  \
# 1339               7  0.525955
# 1341               7  0.503428
# 1343               7  0.499510
# 1340               3  0.493151
# 1338               3  0.483366
# ...              ...       ...
# 1348               3  0.497207
# 1347               7  0.478992
# 1345               7  0.467787
# 1346               3  0.455307
# 1349               7  0.453782
#
#                                           model_dosyasi
# 1339  ../models/xgb_A_subset-Tum_Ozellikler_k5_w7.jo...
# 1341  ../models/xgb_A_subset-Tum_Ozellikler_k10_w7.j...
# 1343  ../models/xgb_A_subset-Sadece_Teknik_Indikator...
# 1340  ../models/xgb_A_subset-Tum_Ozellikler_k10_w3.j...
# 1338  ../models/xgb_A_subset-Tum_Ozellikler_k5_w3.jo...
# ...                                                 ...
# 1348  ../models/xgb_ZTS_subset-Sadece_Teknik_Indikat...
# 1347  ../models/xgb_ZTS_subset-Tum_Ozellikler_k10_w7...
# 1345  ../models/xgb_ZTS_subset-Tum_Ozellikler_k5_w7....
# 1346  ../models/xgb_ZTS_subset-Tum_Ozellikler_k10_w3...
# 1349  ../models/xgb_ZTS_subset-Sadece_Teknik_Indikat...
#
# [2808 rows x 7 columns]
